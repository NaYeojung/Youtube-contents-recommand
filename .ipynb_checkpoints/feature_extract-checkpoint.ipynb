# %% [markdown]
# # 조회수 예측 모델 적용 위한 피쳐 추출

# %% [markdown]
# ## 1. 제목

# %% [markdown]
# #### 후보들 제목 그대로 활용

# %%
import pandas as pd
import re
import emoji
from collections import Counter
from konlpy.tag import Okt

df_recommendations=pd.read_csv('title_recommend_candidates.csv', encoding='utf-8')

# 형태소 분석기 초기화
okt = Okt()

# 불용어 리스트
stopwords = set([
    '은', '는', '이', '가', '을', '를', '에', '의', '도', '로', '과', '와', '한', '하다',
    '에서', '에게', '까지', '부터', '보다', '처럼', '만', '없이', '수', '것', '좀', '더', '이',
    '또', '등', '그', '이것', '저것', '그것', '거', '때', '건', '중', '나', '너', '저', '우리',
    '누구', '뭐', '왜', '어디', '어떻게', '영상', '채널', '오늘', '이제', '정말', '진짜',
    '완전', '그냥', '내가', '당신', '내용', '제목', '시작', '끝', '다시', '모두',
    '최고', '대박', '소름', '헐', 'ㅋㅋ', 'ㅎㅎ', 'ㅠㅠ', '와우','자막','브이','로그','일상',
    '정보', '필독', '업로드', '자막', '구독', '좋아요', '댓글', '시청', '확인', '보세요'
])

# 클릭 유도 키워드
clickbait_keywords = [
    '실화', '충격', '대박', '소름', '반전', '최초', '드디어', '헐', '진실',
    '믿기지', '이게', '무조건', '죽기 전에', '꼭 봐야할'
]

# 제목 기반 피처 추출 함수
def extract_korean_title_features(title, video_id):
    features = {}
    features['video_id'] = video_id
    features['title'] = title
    features['title_length'] = len(title)
    features['word_count'] = len(okt.morphs(title))

    # 이모지 관련 피처
    features['emoji_count'] = sum(1 for char in title if char in emoji.EMOJI_DATA)
    features['has_emoji'] = int(features['emoji_count'] > 0)

    # 특수문자 수
    special_chars = re.findall(r"[!\"#$%&'()*+,\-./:;<=>?@\[\]^_`{|}~]", title)
    features['special_char_count'] = len(special_chars)

    # 클릭유도 키워드 여부
    features['is_clickbait'] = int(any(word in title for word in clickbait_keywords))

    # 구두점
    features['has_question_mark'] = '?' in title
    features['has_exclamation'] = '!' in title

    # 주요 명사 3개
    nouns = okt.nouns(title)
    filtered_nouns = [n for n in nouns if n not in stopwords and len(n) > 1]
    noun_freq = Counter(filtered_nouns)
    top_nouns = [word for word, _ in noun_freq.most_common(3)]
    for i in range(3):
        features[f'top_noun_{i+1}'] = top_nouns[i] if i < len(top_nouns) else ''

    return features

titles = df_recommendations['title_candidate']
video_ids = range(len(titles))  # 후보 고유 ID 부여

title_features_df = pd.DataFrame([
    extract_korean_title_features(title, vid)
    for title, vid in zip(titles, video_ids)
])

title_features_df.head()
# Out:
#    video_id        title  title_length  word_count  ...  has_exclamation  top_noun_1  top_noun_2  top_noun_3
# 0         0      게임 탐험하기             7           3  ...            False          게임          탐험
# 1         1  마인크래프트 탐험하기            11           3  ...            False      마인크래프트          탐험
# 2         2      게임 살펴보기             7           2  ...            False          게임
# 3         3  마인크래프트 살펴보기            11           2  ...            False      마인크래프트
# 4         4      게임 전국일주             7           3  ...            False          게임          전국          일주
#
# [5 rows x 13 columns]

# %% [markdown]
# ## 2. 썸네일

# %% [markdown]
# #### 조회수 예측 모델 학습에 활용한 데이터들의 평균값

# %%
# 썸네일 평균 피처 로드
thumbnail_df = pd.read_csv("../../1학기/캡스톤디자인(1)/Youtube-prediction-and-feedback/model/model_datas.csv")

# feature_cols에 포함된 썸네일 관련 컬럼만 선택
thumbnail_cols = [
    'brightness', 'contrast', 'color_red', 'color_blue', 'color_green',
    'color_yellow', 'color_purple', 'color_brown', 'color_grey', 'color_white', 'color_pink',
    'person_count', 'object_count', 'has_text',
    'person_left', 'person_middle', 'person_right',
    'person_small', 'person_medium', 'person_large',
    'text_left', 'text_middle', 'text_right',
    'text_small', 'text_medium', 'text_large'
]

# ✅ cluster=2인 행만 선택
if 'cluster' in thumbnail_df.columns:
    thumbnail_cluster_df = thumbnail_df[thumbnail_df['cluster'] == 2]
else:
    print("'cluster' 컬럼이 없습니다. 전체 평균으로 계산합니다.")
    thumbnail_cluster_df = thumbnail_df

thumbnail_means = thumbnail_cluster_df[thumbnail_cols].mean().to_dict()
thumbnail_means
# Out:
# {'brightness': 140.29969908503438,
#  'contrast': 70.04647056030761,
#  'color_red': 0.22727272727272727,
#  'color_blue': 0.14015151515151514,
#  'color_green': 0.041666666666666664,
#  'color_yellow': 0.24621212121212122,
#  'color_purple': 0.10606060606060606,
#  'color_brown': 0.49242424242424243,
#  'color_grey': 0.9015151515151515,
#  'color_white': 0.48484848484848486,
#  'color_pink': 0.03787878787878788,
#  'person_count': 1.621212121212121,
#  'object_count': 0.7159090909090909,
#  'has_text': 0.7159090909090909,
#  'person_left': 0.20454545454545456,
#  'person_middle': 1.571969696969697,
#  'person_right': 0.24242424242424243,
#  'person_small': 0.07954545454545454,
#  'person_medium': 1.5757575757575757,
#  'person_large': 1.5909090909090908,
#  'text_left': 0.4015151515151515,
#  'text_middle': 1.3068181818181819,
#  'text_right': 0.3333333333333333,
#  'text_small': 0.4431818181818182,
#  'text_medium': 1.4242424242424243,
#  'text_large': 1.5378787878787878}

# %% [markdown]
# ## 3. 채널 및 영상 정보

# %% [markdown]
# #### 내 채널 데이터들의 평균값

# %%
from datetime import datetime
# === 채널 평균 로드 ===
channel_df = pd.read_csv("data/channel(@KoreanCryingGuy)_videos_metadata.csv")
channel_df = channel_df.rename(columns={'duration_sec':'duration'})
channel_cols = ['duration','subscriber_count']
channel_means = channel_df[channel_cols].mean().to_dict()

# === 현재 시점 게시일 피처 추가 ===
now = datetime.now()
pub_features = {
    'pub_year': now.year,
    'pub_month': now.month,
    'pub_weekday': now.weekday()  # 월=0, 일=6
}

# %%
# === 세 종류의 피처 병합 ===
base_features = {**thumbnail_means, **channel_means, **pub_features}

full_features = []
for _, row in title_features_df.iterrows():
    merged = {**base_features, **row.to_dict()}
    full_features.append(merged)

feature_df = pd.DataFrame(full_features)

# 모델 입력용 feature_cols 순서대로 정리
feature_cols = [
    'duration', 'subscriber_count', 'brightness', 'contrast',
    'title_length', 'word_count', 'emoji_count',
    'special_char_count', 'is_clickbait', 'has_question_mark',
    'has_exclamation', 'pub_year', 'pub_month', 'pub_weekday', 'color_red',
    'color_blue', 'color_green', 'color_yellow', 'color_purple',
    'color_brown', 'color_grey', 'color_white', 'color_pink',
    'person_count', 'object_count', 'has_text', 'person_left',
    'person_middle', 'person_right', 'person_small', 'person_medium',
    'person_large', 'text_left', 'text_middle', 'text_right', 'text_small',
    'text_medium', 'text_large'
]

model_input_df = feature_df[feature_cols + ['title','video_id']]
model_input_df
# Out:
#         duration  subscriber_count  brightness   contrast  ...  text_medium  text_large                      title  video_id
# 0    1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879                    게임 탐험하기         0
# 1    1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879                마인크래프트 탐험하기         1
# 2    1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879                    게임 살펴보기         2
# 3    1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879                마인크래프트 살펴보기         3
# 4    1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879                    게임 전국일주         4
# ..           ...               ...         ...        ...  ...          ...         ...                        ...       ...
# 545  1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879     귀신의집 금지된 학교축제 창자빠지게 놀기       545
# 546  1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879  Lady Ok 금지된 학교축제 창자빠지게 놀기       546
# 547  1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879        찜질방 리모델링기념 창자빠지게 놀기       547
# 548  1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879       귀신의집 리모델링기념 창자빠지게 놀기       548
# 549  1408.662162         1690000.0  140.299699  70.046471  ...     1.424242    1.537879    Lady Ok 리모델링기념 창자빠지게 놀기       549
#
# [550 rows x 40 columns]

# %%
import joblib
import numpy as np
import pandas as pd

# -------------------------------
# 1️⃣ 모델 불러오기
# -------------------------------
model = joblib.load("../../1학기/캡스톤디자인(1)/Youtube-prediction-and-feedback/model/saved_models/model_cluster_2.pkl")

# -------------------------------
# 2️⃣ 예측 수행
# -------------------------------
X = model_input_df[feature_cols]  # 입력 피처만 추출
predicted_views = model.predict(X)

# 결과를 DataFrame에 추가
model_input_df['predicted_views'] = predicted_views

# -------------------------------
# 3️⃣ df_recommendations와 병합
# -------------------------------
# df_recommendations에는 각 제목의 template 정보가 있음
# 로그값을 원래 스케일로 변환
merged_df['predicted_views_actual'] = np.expm1(merged_df['predicted_views'])  # log1p 썼을 경우
# 만약 np.log(view_count+1) 이 아니라 np.log(view_count)만 썼다면 → np.exp()
# merged_df['predicted_views_actual'] = np.exp(merged_df['predicted_views'])

# 템플릿별 최고 조회수 다시 계산
top_titles_by_template = (
    merged_df.sort_values(['template', 'predicted_views'], ascending=[True, False])
    .groupby('template').head(500)
)

# 보기 쉽게 정리
cols_to_show = ['template', 'title_candidate', 'predicted_views_actual']

print(top_titles_by_template[cols_to_show])

# 결과 저장 (선택사항)
# top_titles_by_template.to_csv("top_predicted_titles.csv", index=False, encoding='utf-8-sig')
# Out:
#                                      template                title_candidate  predicted_views_actual
# 103       {ENG} {PERSON}의 {SITUATION} {TOPIC}      ENG SUB 아이유의 웃으면 안되는 생일파티            85251.681473
# 104       {ENG} {PERSON}의 {SITUATION} {TOPIC}       ENG SUB 아이유의 웃으면 안되는 팬미팅            85251.681473
# 105       {ENG} {PERSON}의 {SITUATION} {TOPIC}       ENG SUB 아이유의 떨면 안되는 생일파티            85251.681473
# 106       {ENG} {PERSON}의 {SITUATION} {TOPIC}        ENG SUB 아이유의 떨면 안되는 팬미팅            85251.681473
# 107       {ENG} {PERSON}의 {SITUATION} {TOPIC}      ENG SUB 차은우의 웃으면 안되는 생일파티            85251.681473
# 108       {ENG} {PERSON}의 {SITUATION} {TOPIC}       ENG SUB 차은우의 웃으면 안되는 팬미팅            85251.681473
# 109       {ENG} {PERSON}의 {SITUATION} {TOPIC}       ENG SUB 차은우의 떨면 안되는 생일파티            85251.681473
# 110       {ENG} {PERSON}의 {SITUATION} {TOPIC}        ENG SUB 차은우의 떨면 안되는 팬미팅            85251.681473
# 111       {ENG} {PERSON}의 {SITUATION} {TOPIC}      ENG SUB 라이즈의 웃으면 안되는 생일파티            85251.681473
# 112       {ENG} {PERSON}의 {SITUATION} {TOPIC}       ENG SUB 라이즈의 웃으면 안되는 팬미팅            85251.681473
# 113       {ENG} {PERSON}의 {SITUATION} {TOPIC}       ENG SUB 라이즈의 떨면 안되는 생일파티            85251.681473
# 114       {ENG} {PERSON}의 {SITUATION} {TOPIC}        ENG SUB 라이즈의 떨면 안되는 팬미팅            85251.681473
# 115       {ENG} {PERSON}의 {SITUATION} {TOPIC}          SUB 아이유의 웃으면 안되는 생일파티            85251.681473
# 116       {ENG} {PERSON}의 {SITUATION} {TOPIC}           SUB 아이유의 웃으면 안되는 팬미팅            85251.681473
# 117       {ENG} {PERSON}의 {SITUATION} {TOPIC}           SUB 아이유의 떨면 안되는 생일파티            85251.681473
# 118       {ENG} {PERSON}의 {SITUATION} {TOPIC}            SUB 아이유의 떨면 안되는 팬미팅            85251.681473
# 119       {ENG} {PERSON}의 {SITUATION} {TOPIC}          SUB 차은우의 웃으면 안되는 생일파티            85251.681473
# 120       {ENG} {PERSON}의 {SITUATION} {TOPIC}           SUB 차은우의 웃으면 안되는 팬미팅            85251.681473
# 121       {ENG} {PERSON}의 {SITUATION} {TOPIC}           SUB 차은우의 떨면 안되는 생일파티            85251.681473
# 122       {ENG} {PERSON}의 {SITUATION} {TOPIC}            SUB 차은우의 떨면 안되는 팬미팅            85251.681473
# 123       {ENG} {PERSON}의 {SITUATION} {TOPIC}          SUB 라이즈의 웃으면 안되는 생일파티            85251.681473
# 124       {ENG} {PERSON}의 {SITUATION} {TOPIC}           SUB 라이즈의 웃으면 안되는 팬미팅            85251.681473
# 125       {ENG} {PERSON}의 {SITUATION} {TOPIC}           SUB 라이즈의 떨면 안되는 생일파티            85251.681473
# 126       {ENG} {PERSON}의 {SITUATION} {TOPIC}            SUB 라이즈의 떨면 안되는 팬미팅            85251.681473
# 128       {ENG} {PERSON}의 {SITUATION} {TOPIC}         EN/JP 아이유의 웃으면 안되는 팬미팅            83640.169455
# 130       {ENG} {PERSON}의 {SITUATION} {TOPIC}          EN/JP 아이유의 떨면 안되는 팬미팅            83640.169455
# 132       {ENG} {PERSON}의 {SITUATION} {TOPIC}         EN/JP 차은우의 웃으면 안되는 팬미팅            83640.169455
# 134       {ENG} {PERSON}의 {SITUATION} {TOPIC}          EN/JP 차은우의 떨면 안되는 팬미팅            83640.169455
# 136       {ENG} {PERSON}의 {SITUATION} {TOPIC}         EN/JP 라이즈의 웃으면 안되는 팬미팅            83640.169455
# 138       {ENG} {PERSON}의 {SITUATION} {TOPIC}          EN/JP 라이즈의 떨면 안되는 팬미팅            83640.169455
# 127       {ENG} {PERSON}의 {SITUATION} {TOPIC}        EN/JP 아이유의 웃으면 안되는 생일파티            82923.858366
# 129       {ENG} {PERSON}의 {SITUATION} {TOPIC}         EN/JP 아이유의 떨면 안되는 생일파티            82923.858366
# 131       {ENG} {PERSON}의 {SITUATION} {TOPIC}        EN/JP 차은우의 웃으면 안되는 생일파티            82923.858366
# 133       {ENG} {PERSON}의 {SITUATION} {TOPIC}         EN/JP 차은우의 떨면 안되는 생일파티            82923.858366
# 135       {ENG} {PERSON}의 {SITUATION} {TOPIC}        EN/JP 라이즈의 웃으면 안되는 생일파티            82923.858366
# 137       {ENG} {PERSON}의 {SITUATION} {TOPIC}         EN/JP 라이즈의 떨면 안되는 생일파티            82923.858366
# 142                      {PERSON} {SITUATION}                   감스트 인턴 출근합니다            85251.681473
# 143                      {PERSON} {SITUATION}                   차정원 인턴 출근합니다            85251.681473
# 520   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}         [고나리자] 박규영 총결산 고나리자 00            84960.519485
# 523   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}          [고나리자] 박규영 총결산 냉터뷰 00            84960.519485
# 526   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}          [고나리자] 사나 총결산 고나리자 00            84960.519485
# 529   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}           [고나리자] 사나 총결산 냉터뷰 00            84960.519485
# 532   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}         [고나리자] 강지영 총결산 고나리자 00            84960.519485
# 535   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}          [고나리자] 강지영 총결산 냉터뷰 00            84960.519485
# 522   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}      [사터뷰 시즌2] 박규영 총결산 고나리자 00            81804.657254
# 524   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}      [홍석천의 자석함] 박규영 총결산 냉터뷰 00            81804.657254
# 525   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}       [사터뷰 시즌2] 박규영 총결산 냉터뷰 00            81804.657254
# 527   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}      [홍석천의 자석함] 사나 총결산 고나리자 00            81804.657254
# 528   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}       [사터뷰 시즌2] 사나 총결산 고나리자 00            81804.657254
# 530   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}       [홍석천의 자석함] 사나 총결산 냉터뷰 00            81804.657254
# 531   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}        [사터뷰 시즌2] 사나 총결산 냉터뷰 00            81804.657254
# 534   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}      [사터뷰 시즌2] 강지영 총결산 고나리자 00            81804.657254
# 536   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}      [홍석천의 자석함] 강지영 총결산 냉터뷰 00            81804.657254
# 537   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}       [사터뷰 시즌2] 강지영 총결산 냉터뷰 00            81804.657254
# 521   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}     [홍석천의 자석함] 박규영 총결산 고나리자 00            81441.138726
# 533   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}     [홍석천의 자석함] 강지영 총결산 고나리자 00            81441.138726
# 519           {SERIES} {SITUATION} {REACTION}         [무공해] 해도해도 너무하지만 공감합니다            84232.900790
# 86    {SERIES} {SITUATION} {TOPIC} {REACTION}     [I(D)-CUT] 퇴사마려운 귀여움 잔치 공감           103301.635689
# 77    {SERIES} {SITUATION} {TOPIC} {REACTION}    [I(D)-CUT] 퇴사마려운 귀여움 잔치 레전드           101781.138877
# 95    {SERIES} {SITUATION} {TOPIC} {REACTION}    [I(D)-CUT] 퇴사마려운 귀여움 잔치 귀여움           100825.224165
# 94    {SERIES} {SITUATION} {TOPIC} {REACTION}       [I(D)-CUT] 퇴사마려운 직장인 귀여움            93742.786768
# 96    {SERIES} {SITUATION} {TOPIC} {REACTION}        [I(D)-CUT] 퇴사마려운 빌런 귀여움            93742.786768
# 76    {SERIES} {SITUATION} {TOPIC} {REACTION}       [I(D)-CUT] 퇴사마려운 직장인 레전드            89993.164820
# 78    {SERIES} {SITUATION} {TOPIC} {REACTION}        [I(D)-CUT] 퇴사마려운 빌런 레전드            89993.164820
# 85    {SERIES} {SITUATION} {TOPIC} {REACTION}        [I(D)-CUT] 퇴사마려운 직장인 공감            89993.164820
# 87    {SERIES} {SITUATION} {TOPIC} {REACTION}         [I(D)-CUT] 퇴사마려운 빌런 공감            89993.164820
# 89    {SERIES} {SITUATION} {TOPIC} {REACTION}         [무공해] 퇴사마려운 귀여움 잔치 귀여움            86766.105610
# 92    {SERIES} {SITUATION} {TOPIC} {REACTION}          [웃소] 퇴사마려운 귀여움 잔치 귀여움            86190.733539
# 73    {SERIES} {SITUATION} {TOPIC} {REACTION}             [웃소] 퇴사마려운 직장인 레전드            84960.519485
# 75    {SERIES} {SITUATION} {TOPIC} {REACTION}              [웃소] 퇴사마려운 빌런 레전드            84960.519485
# 82    {SERIES} {SITUATION} {TOPIC} {REACTION}              [웃소] 퇴사마려운 직장인 공감            84960.519485
# 84    {SERIES} {SITUATION} {TOPIC} {REACTION}               [웃소] 퇴사마려운 빌런 공감            84960.519485
# 70    {SERIES} {SITUATION} {TOPIC} {REACTION}            [무공해] 퇴사마려운 직장인 레전드            84232.900790
# 72    {SERIES} {SITUATION} {TOPIC} {REACTION}             [무공해] 퇴사마려운 빌런 레전드            84232.900790
# 79    {SERIES} {SITUATION} {TOPIC} {REACTION}             [무공해] 퇴사마려운 직장인 공감            84232.900790
# 81    {SERIES} {SITUATION} {TOPIC} {REACTION}              [무공해] 퇴사마려운 빌런 공감            84232.900790
# 91    {SERIES} {SITUATION} {TOPIC} {REACTION}             [웃소] 퇴사마려운 직장인 귀여움            84232.900790
# 93    {SERIES} {SITUATION} {TOPIC} {REACTION}              [웃소] 퇴사마려운 빌런 귀여움            84232.900790
# 71    {SERIES} {SITUATION} {TOPIC} {REACTION}         [무공해] 퇴사마려운 귀여움 잔치 레전드            82841.443600
# 80    {SERIES} {SITUATION} {TOPIC} {REACTION}          [무공해] 퇴사마려운 귀여움 잔치 공감            82841.443600
# 74    {SERIES} {SITUATION} {TOPIC} {REACTION}          [웃소] 퇴사마려운 귀여움 잔치 레전드            81804.657254
# 83    {SERIES} {SITUATION} {TOPIC} {REACTION}           [웃소] 퇴사마려운 귀여움 잔치 공감            81804.657254
# 88    {SERIES} {SITUATION} {TOPIC} {REACTION}            [무공해] 퇴사마려운 직장인 귀여움            81804.657254
# 90    {SERIES} {SITUATION} {TOPIC} {REACTION}             [무공해] 퇴사마려운 빌런 귀여움            81804.657254
# 37                     {SERIES} {TOPIC} {ENG}              [한화 이글스] 노래 모음 플리            84960.519485
# 38                     {SERIES} {TOPIC} {ENG}            [KIA 타이거즈] 노래 모음 플리            84960.519485
# 39                     {SERIES} {TOPIC} {ENG}            [LG TWINS] 노래 모음 플리            84960.519485
# 40                   {SERIES} {TOPIC} {EVENT}               [예고] 다크소울 플레이리스트            84960.519485
# 41                   {SERIES} {TOPIC} {EVENT}               [예고] 고민중독 플레이리스트            84960.519485
# 42                   {SERIES} {TOPIC} {EVENT}               [예고] 아이디어 플레이리스트            84960.519485
# 43                   {SERIES} {TOPIC} {EVENT}             [다크소울] 다크소울 플레이리스트            84960.519485
# 44                   {SERIES} {TOPIC} {EVENT}             [다크소울] 고민중독 플레이리스트            84960.519485
# 45                   {SERIES} {TOPIC} {EVENT}             [다크소울] 아이디어 플레이리스트            84960.519485
# 46                   {SERIES} {TOPIC} {EVENT}                 [예고] 다크소울 브이로그            84960.519485
# 47                   {SERIES} {TOPIC} {EVENT}                 [예고] 고민중독 브이로그            84960.519485
# 48                   {SERIES} {TOPIC} {EVENT}                 [예고] 아이디어 브이로그            84960.519485
# 49                   {SERIES} {TOPIC} {EVENT}               [다크소울] 다크소울 브이로그            84960.519485
# 50                   {SERIES} {TOPIC} {EVENT}               [다크소울] 고민중독 브이로그            84960.519485
# 51                   {SERIES} {TOPIC} {EVENT}               [다크소울] 아이디어 브이로그            84960.519485
# 52                   {SERIES} {TOPIC} {EVENT}                   [예고] 다크소울 플리            84960.519485
# 53                   {SERIES} {TOPIC} {EVENT}                   [예고] 고민중독 플리            84960.519485
# 54                   {SERIES} {TOPIC} {EVENT}                   [예고] 아이디어 플리            84960.519485
# 55                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 다크소울 플리            84960.519485
# 56                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 고민중독 플리            84960.519485
# 57                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 아이디어 플리            84960.519485
# 58                   {SERIES} {TOPIC} {EVENT}                   [예고] 다크소울 먹방            84960.519485
# 59                   {SERIES} {TOPIC} {EVENT}                   [예고] 고민중독 먹방            84960.519485
# 60                   {SERIES} {TOPIC} {EVENT}                   [예고] 아이디어 먹방            84960.519485
# 61                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 다크소울 먹방            84960.519485
# 62                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 고민중독 먹방            84960.519485
# 63                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 아이디어 먹방            84960.519485
# 64                   {SERIES} {TOPIC} {EVENT}                   [예고] 다크소울 모음            84960.519485
# 65                   {SERIES} {TOPIC} {EVENT}                   [예고] 고민중독 모음            84960.519485
# 66                   {SERIES} {TOPIC} {EVENT}                   [예고] 아이디어 모음            84960.519485
# 67                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 다크소울 모음            84960.519485
# 68                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 고민중독 모음            84960.519485
# 69                   {SERIES} {TOPIC} {EVENT}                 [다크소울] 아이디어 모음            84960.519485
# 144  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 여행 롯데 00            84960.519485
# 145  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 여행 롯데 00            84960.519485
# 146  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 여행 롯데 00            84960.519485
# 147  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 여행 롯데 00            84960.519485
# 149  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 먹방 롯데 00            84960.519485
# 150  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 먹방 롯데 00            84960.519485
# 151  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 먹방 롯데 00            84960.519485
# 152  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 먹방 롯데 00            84960.519485
# 154  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 전쟁 이야기 롯데 00            84960.519485
# 155  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 전쟁 이야기 롯데 00            84960.519485
# 156  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 전쟁 이야기 롯데 00            84960.519485
# 157  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 전쟁 이야기 롯데 00            84960.519485
# 159  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 전쟁 해봤습니다 롯데 00            84960.519485
# 160  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 전쟁 해봤습니다 롯데 00            84960.519485
# 161  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 전쟁 해봤습니다 롯데 00            84960.519485
# 162  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 전쟁 해봤습니다 롯데 00            84960.519485
# 164  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 전쟁 with 롯데 00            84960.519485
# 165  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 전쟁 with 롯데 00            84960.519485
# 166  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 전쟁 with 롯데 00            84960.519485
# 167  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 전쟁 with 롯데 00            84960.519485
# 169  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 여행 한국 00            84960.519485
# 170  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 여행 한국 00            84960.519485
# 171  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 여행 한국 00            84960.519485
# 172  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 여행 한국 00            84960.519485
# 174  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 먹방 한국 00            84960.519485
# 175  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 먹방 한국 00            84960.519485
# 176  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 먹방 한국 00            84960.519485
# 177  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 먹방 한국 00            84960.519485
# 179  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 전쟁 이야기 한국 00            84960.519485
# 180  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 전쟁 이야기 한국 00            84960.519485
# 181  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 전쟁 이야기 한국 00            84960.519485
# 182  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 전쟁 이야기 한국 00            84960.519485
# 184  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 전쟁 해봤습니다 한국 00            84960.519485
# 185  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 전쟁 해봤습니다 한국 00            84960.519485
# 186  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 전쟁 해봤습니다 한국 00            84960.519485
# 187  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 전쟁 해봤습니다 한국 00            84960.519485
# 189  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 전쟁 with 한국 00            84960.519485
# 190  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 전쟁 with 한국 00            84960.519485
# 191  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 전쟁 with 한국 00            84960.519485
# 192  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 전쟁 with 한국 00            84960.519485
# 219  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 여행 부산 00            84960.519485
# 220  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 여행 부산 00            84960.519485
# 221  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 여행 부산 00            84960.519485
# 222  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 여행 부산 00            84960.519485
# 224  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 먹방 부산 00            84960.519485
# 225  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 먹방 부산 00            84960.519485
# 226  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 먹방 부산 00            84960.519485
# 227  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 먹방 부산 00            84960.519485
# 229  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 전쟁 이야기 부산 00            84960.519485
# 230  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 전쟁 이야기 부산 00            84960.519485
# 231  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 전쟁 이야기 부산 00            84960.519485
# 232  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 전쟁 이야기 부산 00            84960.519485
# 234  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 전쟁 해봤습니다 부산 00            84960.519485
# 235  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 전쟁 해봤습니다 부산 00            84960.519485
# 236  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 전쟁 해봤습니다 부산 00            84960.519485
# 237  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 전쟁 해봤습니다 부산 00            84960.519485
# 239  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 전쟁 with 부산 00            84960.519485
# 240  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 전쟁 with 부산 00            84960.519485
# 241  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 전쟁 with 부산 00            84960.519485
# 242  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 전쟁 with 부산 00            84960.519485
# 244  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 여행 광주 00            84960.519485
# 245  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 여행 광주 00            84960.519485
# 246  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 여행 광주 00            84960.519485
# 247  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 여행 광주 00            84960.519485
# 249  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [sub] 전쟁 먹방 광주 00            84960.519485
# 250  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [무공해] 전쟁 먹방 광주 00            84960.519485
# 251  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플레이리스트] 전쟁 먹방 광주 00            84960.519485
# 252  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}               [플리] 전쟁 먹방 광주 00            84960.519485
# 254  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 전쟁 이야기 광주 00            84960.519485
# 255  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 전쟁 이야기 광주 00            84960.519485
# 256  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 전쟁 이야기 광주 00            84960.519485
# 257  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 전쟁 이야기 광주 00            84960.519485
# 259  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 전쟁 해봤습니다 광주 00            84960.519485
# 260  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 전쟁 해봤습니다 광주 00            84960.519485
# 261  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 전쟁 해봤습니다 광주 00            84960.519485
# 262  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 전쟁 해봤습니다 광주 00            84960.519485
# 264  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 전쟁 with 광주 00            84960.519485
# 265  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 전쟁 with 광주 00            84960.519485
# 266  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 전쟁 with 광주 00            84960.519485
# 267  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 전쟁 with 광주 00            84960.519485
# 269  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 여행 롯데 00            84960.519485
# 270  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 여행 롯데 00            84960.519485
# 271  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 여행 롯데 00            84960.519485
# 272  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 여행 롯데 00            84960.519485
# 274  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 먹방 롯데 00            84960.519485
# 275  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 먹방 롯데 00            84960.519485
# 276  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 먹방 롯데 00            84960.519485
# 277  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 먹방 롯데 00            84960.519485
# 279  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 파르페 이야기 롯데 00            84960.519485
# 280  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 파르페 이야기 롯데 00            84960.519485
# 281  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 파르페 이야기 롯데 00            84960.519485
# 282  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 파르페 이야기 롯데 00            84960.519485
# 284  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 파르페 해봤습니다 롯데 00            84960.519485
# 285  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 파르페 해봤습니다 롯데 00            84960.519485
# 286  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 파르페 해봤습니다 롯데 00            84960.519485
# 287  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 파르페 해봤습니다 롯데 00            84960.519485
# 289  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 파르페 with 롯데 00            84960.519485
# 290  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 파르페 with 롯데 00            84960.519485
# 291  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 파르페 with 롯데 00            84960.519485
# 292  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 파르페 with 롯데 00            84960.519485
# 294  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 여행 한국 00            84960.519485
# 295  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 여행 한국 00            84960.519485
# 296  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 여행 한국 00            84960.519485
# 297  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 여행 한국 00            84960.519485
# 299  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 먹방 한국 00            84960.519485
# 300  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 먹방 한국 00            84960.519485
# 301  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 먹방 한국 00            84960.519485
# 302  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 먹방 한국 00            84960.519485
# 304  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 파르페 이야기 한국 00            84960.519485
# 305  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 파르페 이야기 한국 00            84960.519485
# 306  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 파르페 이야기 한국 00            84960.519485
# 307  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 파르페 이야기 한국 00            84960.519485
# 309  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 파르페 해봤습니다 한국 00            84960.519485
# 310  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 파르페 해봤습니다 한국 00            84960.519485
# 311  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 파르페 해봤습니다 한국 00            84960.519485
# 312  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 파르페 해봤습니다 한국 00            84960.519485
# 314  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 파르페 with 한국 00            84960.519485
# 315  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 파르페 with 한국 00            84960.519485
# 316  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 파르페 with 한국 00            84960.519485
# 317  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 파르페 with 한국 00            84960.519485
# 344  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 여행 부산 00            84960.519485
# 345  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 여행 부산 00            84960.519485
# 346  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 여행 부산 00            84960.519485
# 347  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 여행 부산 00            84960.519485
# 349  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 먹방 부산 00            84960.519485
# 350  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 먹방 부산 00            84960.519485
# 351  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 먹방 부산 00            84960.519485
# 352  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 먹방 부산 00            84960.519485
# 354  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 파르페 이야기 부산 00            84960.519485
# 355  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 파르페 이야기 부산 00            84960.519485
# 356  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 파르페 이야기 부산 00            84960.519485
# 357  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 파르페 이야기 부산 00            84960.519485
# 359  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 파르페 해봤습니다 부산 00            84960.519485
# 360  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 파르페 해봤습니다 부산 00            84960.519485
# 361  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 파르페 해봤습니다 부산 00            84960.519485
# 362  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 파르페 해봤습니다 부산 00            84960.519485
# 364  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 파르페 with 부산 00            84960.519485
# 365  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 파르페 with 부산 00            84960.519485
# 366  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 파르페 with 부산 00            84960.519485
# 367  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 파르페 with 부산 00            84960.519485
# 369  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 여행 광주 00            84960.519485
# 370  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 여행 광주 00            84960.519485
# 371  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 여행 광주 00            84960.519485
# 372  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 여행 광주 00            84960.519485
# 374  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 파르페 먹방 광주 00            84960.519485
# 375  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 파르페 먹방 광주 00            84960.519485
# 376  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 파르페 먹방 광주 00            84960.519485
# 377  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 파르페 먹방 광주 00            84960.519485
# 379  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 파르페 이야기 광주 00            84960.519485
# 380  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 파르페 이야기 광주 00            84960.519485
# 381  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 파르페 이야기 광주 00            84960.519485
# 382  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 파르페 이야기 광주 00            84960.519485
# 384  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 파르페 해봤습니다 광주 00            84960.519485
# 385  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 파르페 해봤습니다 광주 00            84960.519485
# 386  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 파르페 해봤습니다 광주 00            84960.519485
# 387  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 파르페 해봤습니다 광주 00            84960.519485
# 389  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 파르페 with 광주 00            84960.519485
# 390  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 파르페 with 광주 00            84960.519485
# 391  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 파르페 with 광주 00            84960.519485
# 392  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 파르페 with 광주 00            84960.519485
# 394  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 여행 롯데 00            84960.519485
# 395  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 여행 롯데 00            84960.519485
# 396  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 여행 롯데 00            84960.519485
# 397  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 여행 롯데 00            84960.519485
# 399  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 먹방 롯데 00            84960.519485
# 400  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 먹방 롯데 00            84960.519485
# 401  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 먹방 롯데 00            84960.519485
# 402  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 먹방 롯데 00            84960.519485
# 404  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 베트남 이야기 롯데 00            84960.519485
# 405  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 베트남 이야기 롯데 00            84960.519485
# 406  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 베트남 이야기 롯데 00            84960.519485
# 407  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 베트남 이야기 롯데 00            84960.519485
# 409  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 베트남 해봤습니다 롯데 00            84960.519485
# 410  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 베트남 해봤습니다 롯데 00            84960.519485
# 411  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 베트남 해봤습니다 롯데 00            84960.519485
# 412  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 베트남 해봤습니다 롯데 00            84960.519485
# 414  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 베트남 with 롯데 00            84960.519485
# 415  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 베트남 with 롯데 00            84960.519485
# 416  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 베트남 with 롯데 00            84960.519485
# 417  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 베트남 with 롯데 00            84960.519485
# 419  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 여행 한국 00            84960.519485
# 420  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 여행 한국 00            84960.519485
# 421  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 여행 한국 00            84960.519485
# 422  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 여행 한국 00            84960.519485
# 424  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 먹방 한국 00            84960.519485
# 425  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 먹방 한국 00            84960.519485
# 426  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 먹방 한국 00            84960.519485
# 427  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 먹방 한국 00            84960.519485
# 429  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 베트남 이야기 한국 00            84960.519485
# 430  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 베트남 이야기 한국 00            84960.519485
# 431  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 베트남 이야기 한국 00            84960.519485
# 432  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 베트남 이야기 한국 00            84960.519485
# 434  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 베트남 해봤습니다 한국 00            84960.519485
# 435  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 베트남 해봤습니다 한국 00            84960.519485
# 436  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 베트남 해봤습니다 한국 00            84960.519485
# 437  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 베트남 해봤습니다 한국 00            84960.519485
# 439  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 베트남 with 한국 00            84960.519485
# 440  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 베트남 with 한국 00            84960.519485
# 441  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 베트남 with 한국 00            84960.519485
# 442  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 베트남 with 한국 00            84960.519485
# 469  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 여행 부산 00            84960.519485
# 470  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 여행 부산 00            84960.519485
# 471  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 여행 부산 00            84960.519485
# 472  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 여행 부산 00            84960.519485
# 474  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 먹방 부산 00            84960.519485
# 475  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 먹방 부산 00            84960.519485
# 476  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 먹방 부산 00            84960.519485
# 477  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 먹방 부산 00            84960.519485
# 479  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 베트남 이야기 부산 00            84960.519485
# 480  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 베트남 이야기 부산 00            84960.519485
# 481  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 베트남 이야기 부산 00            84960.519485
# 482  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 베트남 이야기 부산 00            84960.519485
# 484  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 베트남 해봤습니다 부산 00            84960.519485
# 485  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 베트남 해봤습니다 부산 00            84960.519485
# 486  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 베트남 해봤습니다 부산 00            84960.519485
# 487  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 베트남 해봤습니다 부산 00            84960.519485
# 489  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 베트남 with 부산 00            84960.519485
# 490  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 베트남 with 부산 00            84960.519485
# 491  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 베트남 with 부산 00            84960.519485
# 492  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 베트남 with 부산 00            84960.519485
# 494  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 여행 광주 00            84960.519485
# 495  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 여행 광주 00            84960.519485
# 496  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 여행 광주 00            84960.519485
# 497  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 여행 광주 00            84960.519485
# 499  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 먹방 광주 00            84960.519485
# 500  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [무공해] 베트남 먹방 광주 00            84960.519485
# 501  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플레이리스트] 베트남 먹방 광주 00            84960.519485
# 502  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}              [플리] 베트남 먹방 광주 00            84960.519485
# 504  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [sub] 베트남 이야기 광주 00            84960.519485
# 505  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [무공해] 베트남 이야기 광주 00            84960.519485
# 506  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플레이리스트] 베트남 이야기 광주 00            84960.519485
# 507  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [플리] 베트남 이야기 광주 00            84960.519485
# 509  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [sub] 베트남 해봤습니다 광주 00            84960.519485
# 510  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [무공해] 베트남 해봤습니다 광주 00            84960.519485
# 511  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플레이리스트] 베트남 해봤습니다 광주 00            84960.519485
# 512  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [플리] 베트남 해봤습니다 광주 00            84960.519485
# 514  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [sub] 베트남 with 광주 00            84960.519485
# 515  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [무공해] 베트남 with 광주 00            84960.519485
# 516  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플레이리스트] 베트남 with 광주 00            84960.519485
# 517  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}            [플리] 베트남 with 광주 00            84960.519485
# 148  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 여행 롯데 00            84232.900790
# 153  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 먹방 롯데 00            84232.900790
# 158  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 전쟁 이야기 롯데 00            84232.900790
# 163  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 전쟁 해봤습니다 롯데 00            84232.900790
# 168  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 전쟁 with 롯데 00            84232.900790
# 173  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 여행 한국 00            84232.900790
# 178  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 먹방 한국 00            84232.900790
# 183  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 전쟁 이야기 한국 00            84232.900790
# 188  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 전쟁 해봤습니다 한국 00            84232.900790
# 193  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 전쟁 with 한국 00            84232.900790
# 194  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [sub] 전쟁 여행 국립경국대학교 00            84232.900790
# 195  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [무공해] 전쟁 여행 국립경국대학교 00            84232.900790
# 196  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [플레이리스트] 전쟁 여행 국립경국대학교 00            84232.900790
# 197  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플리] 전쟁 여행 국립경국대학교 00            84232.900790
# 199  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [sub] 전쟁 먹방 국립경국대학교 00            84232.900790
# 200  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [무공해] 전쟁 먹방 국립경국대학교 00            84232.900790
# 201  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [플레이리스트] 전쟁 먹방 국립경국대학교 00            84232.900790
# 202  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [플리] 전쟁 먹방 국립경국대학교 00            84232.900790
# 204  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [sub] 전쟁 이야기 국립경국대학교 00            84232.900790
# 205  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [무공해] 전쟁 이야기 국립경국대학교 00            84232.900790
# 207  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플리] 전쟁 이야기 국립경국대학교 00            84232.900790
# 209  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [sub] 전쟁 해봤습니다 국립경국대학교 00            84232.900790
# 210  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [무공해] 전쟁 해봤습니다 국립경국대학교 00            84232.900790
# 212  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플리] 전쟁 해봤습니다 국립경국대학교 00            84232.900790
# 214  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [sub] 전쟁 with 국립경국대학교 00            84232.900790
# 215  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [무공해] 전쟁 with 국립경국대학교 00            84232.900790
# 217  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플리] 전쟁 with 국립경국대학교 00            84232.900790
# 223  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 여행 부산 00            84232.900790
# 228  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 먹방 부산 00            84232.900790
# 233  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 전쟁 이야기 부산 00            84232.900790
# 238  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 전쟁 해봤습니다 부산 00            84232.900790
# 243  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 전쟁 with 부산 00            84232.900790
# 248  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 여행 광주 00            84232.900790
# 253  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}           [틀린그림찾기] 전쟁 먹방 광주 00            84232.900790
# 258  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 전쟁 이야기 광주 00            84232.900790
# 263  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 전쟁 해봤습니다 광주 00            84232.900790
# 268  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 전쟁 with 광주 00            84232.900790
# 273  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 여행 롯데 00            84232.900790
# 278  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 먹방 롯데 00            84232.900790
# 283  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 파르페 이야기 롯데 00            84232.900790
# 288  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 파르페 해봤습니다 롯데 00            84232.900790
# 293  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 파르페 with 롯데 00            84232.900790
# 298  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 여행 한국 00            84232.900790
# 303  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 먹방 한국 00            84232.900790
# 308  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 파르페 이야기 한국 00            84232.900790
# 313  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 파르페 해봤습니다 한국 00            84232.900790
# 318  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 파르페 with 한국 00            84232.900790
# 319  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [sub] 파르페 여행 국립경국대학교 00            84232.900790
# 320  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [무공해] 파르페 여행 국립경국대학교 00            84232.900790
# 322  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플리] 파르페 여행 국립경국대학교 00            84232.900790
# 324  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [sub] 파르페 먹방 국립경국대학교 00            84232.900790
# 325  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [무공해] 파르페 먹방 국립경국대학교 00            84232.900790
# 327  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플리] 파르페 먹방 국립경국대학교 00            84232.900790
# 329  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [sub] 파르페 이야기 국립경국대학교 00            84232.900790
# 330  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [무공해] 파르페 이야기 국립경국대학교 00            84232.900790
# 332  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플리] 파르페 이야기 국립경국대학교 00            84232.900790
# 337  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [플리] 파르페 해봤습니다 국립경국대학교 00            84232.900790
# 339  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [sub] 파르페 with 국립경국대학교 00            84232.900790
# 340  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [무공해] 파르페 with 국립경국대학교 00            84232.900790
# 342  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플리] 파르페 with 국립경국대학교 00            84232.900790
# 348  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 여행 부산 00            84232.900790
# 353  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 먹방 부산 00            84232.900790
# 358  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 파르페 이야기 부산 00            84232.900790
# 363  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 파르페 해봤습니다 부산 00            84232.900790
# 368  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 파르페 with 부산 00            84232.900790
# 373  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 여행 광주 00            84232.900790
# 378  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 파르페 먹방 광주 00            84232.900790
# 383  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 파르페 이야기 광주 00            84232.900790
# 388  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 파르페 해봤습니다 광주 00            84232.900790
# 393  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 파르페 with 광주 00            84232.900790
# 398  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 여행 롯데 00            84232.900790
# 403  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 먹방 롯데 00            84232.900790
# 408  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 베트남 이야기 롯데 00            84232.900790
# 413  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 베트남 해봤습니다 롯데 00            84232.900790
# 418  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 베트남 with 롯데 00            84232.900790
# 423  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 여행 한국 00            84232.900790
# 428  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 먹방 한국 00            84232.900790
# 433  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 베트남 이야기 한국 00            84232.900790
# 438  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 베트남 해봤습니다 한국 00            84232.900790
# 443  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 베트남 with 한국 00            84232.900790
# 444  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [sub] 베트남 여행 국립경국대학교 00            84232.900790
# 445  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [무공해] 베트남 여행 국립경국대학교 00            84232.900790
# 447  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플리] 베트남 여행 국립경국대학교 00            84232.900790
# 449  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [sub] 베트남 먹방 국립경국대학교 00            84232.900790
# 450  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [무공해] 베트남 먹방 국립경국대학교 00            84232.900790
# 452  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [플리] 베트남 먹방 국립경국대학교 00            84232.900790
# 454  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [sub] 베트남 이야기 국립경국대학교 00            84232.900790
# 455  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [무공해] 베트남 이야기 국립경국대학교 00            84232.900790
# 457  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [플리] 베트남 이야기 국립경국대학교 00            84232.900790
# 462  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [플리] 베트남 해봤습니다 국립경국대학교 00            84232.900790
# 464  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [sub] 베트남 with 국립경국대학교 00            84232.900790
# 465  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [무공해] 베트남 with 국립경국대학교 00            84232.900790
# 467  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [플리] 베트남 with 국립경국대학교 00            84232.900790
# 473  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 여행 부산 00            84232.900790
# 478  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 먹방 부산 00            84232.900790
# 483  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 베트남 이야기 부산 00            84232.900790
# 488  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 베트남 해봤습니다 부산 00            84232.900790
# 493  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 베트남 with 부산 00            84232.900790
# 498  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 여행 광주 00            84232.900790
# 503  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}          [틀린그림찾기] 베트남 먹방 광주 00            84232.900790
# 508  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}         [틀린그림찾기] 베트남 이야기 광주 00            84232.900790
# 513  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}       [틀린그림찾기] 베트남 해봤습니다 광주 00            84232.900790
# 518  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}        [틀린그림찾기] 베트남 with 광주 00            84232.900790
# 206  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [플레이리스트] 전쟁 이야기 국립경국대학교 00            83858.591914
# 321  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [플레이리스트] 파르페 여행 국립경국대학교 00            83858.591914
# 326  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [플레이리스트] 파르페 먹방 국립경국대학교 00            83858.591914
# 334  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [sub] 파르페 해봤습니다 국립경국대학교 00            83858.591914
# 335  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [무공해] 파르페 해봤습니다 국립경국대학교 00            83858.591914
# 446  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [플레이리스트] 베트남 여행 국립경국대학교 00            83858.591914
# 451  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [플레이리스트] 베트남 먹방 국립경국대학교 00            83858.591914
# 459  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [sub] 베트남 해봤습니다 국립경국대학교 00            83858.591914
# 460  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [무공해] 베트남 해봤습니다 국립경국대학교 00            83858.591914
# 211  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}   [플레이리스트] 전쟁 해봤습니다 국립경국대학교 00            82035.475465
# 216  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}    [플레이리스트] 전쟁 with 국립경국대학교 00            82035.475465
# 331  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}    [플레이리스트] 파르페 이야기 국립경국대학교 00            82035.475465
# 341  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}   [플레이리스트] 파르페 with 국립경국대학교 00            82035.475465
# 456  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}    [플레이리스트] 베트남 이야기 국립경국대학교 00            82035.475465
# 466  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}   [플레이리스트] 베트남 with 국립경국대학교 00            82035.475465
# 198  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [틀린그림찾기] 전쟁 여행 국립경국대학교 00            81804.657254
# 203  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}      [틀린그림찾기] 전쟁 먹방 국립경국대학교 00            81804.657254
# 336  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}  [플레이리스트] 파르페 해봤습니다 국립경국대학교 00            81548.518599
# 461  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}  [플레이리스트] 베트남 해봤습니다 국립경국대학교 00            81548.518599
# 208  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [틀린그림찾기] 전쟁 이야기 국립경국대학교 00            81441.138726
# 323  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [틀린그림찾기] 파르페 여행 국립경국대학교 00            81441.138726
# 328  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [틀린그림찾기] 파르페 먹방 국립경국대학교 00            81441.138726
# 448  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [틀린그림찾기] 베트남 여행 국립경국대학교 00            81441.138726
# 453  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}     [틀린그림찾기] 베트남 먹방 국립경국대학교 00            81441.138726
# 213  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}   [틀린그림찾기] 전쟁 해봤습니다 국립경국대학교 00            79670.577967
# 218  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}    [틀린그림찾기] 전쟁 with 국립경국대학교 00            79670.577967
# 333  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}    [틀린그림찾기] 파르페 이야기 국립경국대학교 00            79670.577967
# 343  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}   [틀린그림찾기] 파르페 with 국립경국대학교 00            79670.577967
# 458  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}    [틀린그림찾기] 베트남 이야기 국립경국대학교 00            79670.577967
# 468  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}   [틀린그림찾기] 베트남 with 국립경국대학교 00            79670.577967
# 338  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}  [틀린그림찾기] 파르페 해봤습니다 국립경국대학교 00            79197.658796
# 463  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}  [틀린그림찾기] 베트남 해봤습니다 국립경국대학교 00            79197.658796
# 139  {SERIES} {TOPIC} {SITUATION} {NUM} {ENG}      [카니를 찾아서] 돈가스 생기는 일 00 EN            84232.900790
# 140  {SERIES} {TOPIC} {SITUATION} {NUM} {ENG}          [영업중] 돈가스 생기는 일 00 EN            84232.900790
# 141  {SERIES} {TOPIC} {SITUATION} {NUM} {ENG}   [어서와한국은처음이지] 돈가스 생기는 일 00 EN            83942.233870
# 10                        {SITUATION} {TOPIC}                          대결 미래            85251.681473
# 11                        {SITUATION} {TOPIC}                         대결 기념일            85251.681473
# 12                        {SITUATION} {TOPIC}                        대결 개유치한            85251.681473
# 13                        {SITUATION} {TOPIC}                         맞히기 미래            85251.681473
# 14                        {SITUATION} {TOPIC}                        맞히기 기념일            85251.681473
# 15                        {SITUATION} {TOPIC}                       맞히기 개유치한            85251.681473
# 16                        {SITUATION} {TOPIC}                        틀어놓고 미래            85251.681473
# 17                        {SITUATION} {TOPIC}                       틀어놓고 기념일            85251.681473
# 18                        {SITUATION} {TOPIC}                      틀어놓고 개유치한            85251.681473
# 19                        {SITUATION} {TOPIC}                그냥 내비대로 가주세요 미래            85251.681473
# 20                        {SITUATION} {TOPIC}               그냥 내비대로 가주세요 기념일            85251.681473
# 21                        {SITUATION} {TOPIC}              그냥 내비대로 가주세요 개유치한            85251.681473
# 22                            {TOPIC} {EVENT}                   퇴사자 당근마켓 레전드            85251.681473
# 23                            {TOPIC} {EVENT}                 심연의 끝 당근마켓 레전드            85251.681473
# 24                            {TOPIC} {EVENT}                    구원 당근마켓 레전드            85251.681473
# 25                            {TOPIC} {EVENT}                       퇴사자 걸스나잇            85251.681473
# 26                            {TOPIC} {EVENT}                     심연의 끝 걸스나잇            85251.681473
# 27                            {TOPIC} {EVENT}                        구원 걸스나잇            85251.681473
# 28                            {TOPIC} {EVENT}                          퇴사자 킬            85251.681473
# 29                            {TOPIC} {EVENT}                        심연의 끝 킬            85251.681473
# 30                            {TOPIC} {EVENT}                           구원 킬            85251.681473
# 31                            {TOPIC} {EVENT}                        퇴사자 워크샵            85251.681473
# 32                            {TOPIC} {EVENT}                      심연의 끝 워크샵            85251.681473
# 33                            {TOPIC} {EVENT}                         구원 워크샵            85251.681473
# 34                            {TOPIC} {EVENT}                       퇴사자 Best            85251.681473
# 35                            {TOPIC} {EVENT}                     심연의 끝 Best            85251.681473
# 36                            {TOPIC} {EVENT}                        구원 Best            85251.681473
# 544               {TOPIC} {EVENT} {SITUATION}          찜질방 금지된 학교축제 창자빠지게 놀기            85251.681473
# 545               {TOPIC} {EVENT} {SITUATION}         귀신의집 금지된 학교축제 창자빠지게 놀기            85251.681473
# 547               {TOPIC} {EVENT} {SITUATION}            찜질방 리모델링기념 창자빠지게 놀기            85251.681473
# 548               {TOPIC} {EVENT} {SITUATION}           귀신의집 리모델링기념 창자빠지게 놀기            85251.681473
# 549               {TOPIC} {EVENT} {SITUATION}        Lady Ok 리모델링기념 창자빠지게 놀기            85251.681473
# 546               {TOPIC} {EVENT} {SITUATION}      Lady Ok 금지된 학교축제 창자빠지게 놀기            84521.569239
# 0                         {TOPIC} {SITUATION}                        게임 탐험하기            85251.681473
# 1                         {TOPIC} {SITUATION}                    마인크래프트 탐험하기            85251.681473
# 2                         {TOPIC} {SITUATION}                        게임 살펴보기            85251.681473
# 3                         {TOPIC} {SITUATION}                    마인크래프트 살펴보기            85251.681473
# 4                         {TOPIC} {SITUATION}                        게임 전국일주            85251.681473
# 5                         {TOPIC} {SITUATION}                    마인크래프트 전국일주            85251.681473
# 6                         {TOPIC} {SITUATION}                       게임 낉여오너라            85251.681473
# 7                         {TOPIC} {SITUATION}                   마인크래프트 낉여오너라            85251.681473
# 8                         {TOPIC} {SITUATION}                       게임 하루 탕진            85251.681473
# 9                         {TOPIC} {SITUATION}                   마인크래프트 하루 탕진            85251.681473
# 538                 {TOPIC} {SITUATION} {ENG}                    노래 잘못된 브이로그            85251.681473
# 539                 {TOPIC} {SITUATION} {ENG}                    팝송 잘못된 브이로그            85251.681473
# 540                 {TOPIC} {SITUATION} {ENG}                 템플스테이 잘못된 브이로그            85251.681473
# 541                 {TOPIC} {SITUATION} {ENG}                      노래 잘못된 플리            85251.681473
# 542                 {TOPIC} {SITUATION} {ENG}                      팝송 잘못된 플리            85251.681473
# 543                 {TOPIC} {SITUATION} {ENG}                   템플스테이 잘못된 플리            85251.681473
# 97                  {TOPIC} {SITUATION} {LOC}                 여행 쓸쓸하지 않은 제주도            85251.681473
# 98                  {TOPIC} {SITUATION} {LOC}                  여행 쓸쓸하지 않은 태국            85251.681473
# 99                  {TOPIC} {SITUATION} {LOC}                여행 쓸쓸하지 않은 오키나와            85251.681473
# 100                 {TOPIC} {SITUATION} {LOC}                편의점 쓸쓸하지 않은 제주도            85251.681473
# 101                 {TOPIC} {SITUATION} {LOC}                 편의점 쓸쓸하지 않은 태국            85251.681473
# 102                 {TOPIC} {SITUATION} {LOC}               편의점 쓸쓸하지 않은 오키나와            85251.681473
# C:\Users\duwjd\AppData\Local\Temp\ipykernel_6788\4095777548.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_input_df['predicted_views'] = predicted_views

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
def build_prompt(template, candidates, avg_features, top10_features):
    prompt = f"""
You are an expert YouTube strategist who improves Korean titles to maximize views.

Below are candidate titles for a YouTube video template:
Template: {template}
Candidates:
{chr(10).join('- ' + c for c in candidates)}

We analyzed 1000 videos from this channel. 
Here are the style statistics for Cluster 2 videos and their Top 10% performers.

[Cluster 2 Average Style]
- Title length: {avg_features['title_length']} characters
- Word count: {avg_features['word_count']}
- Emoji count: {avg_features['emoji_count']}
- Special characters: {avg_features['special_char_count']}
- Clickbait presence: {avg_features['is_clickbait']}
- Has question mark: {avg_features['has_question_mark']}
- Has exclamation mark: {avg_features['has_exclamation']}

[Top 10% Average Style]
- Title length: {top10_features['title_length']} characters
- Word count: {top10_features['word_count']}
- Emoji count: {top10_features['emoji_count']}
- Special characters: {top10_features['special_char_count']}
- Clickbait presence: {top10_features['is_clickbait']}
- Has question mark: {top10_features['has_question_mark']}
- Has exclamation mark: {top10_features['has_exclamation']}

Goal:
- Modify or slightly improve one candidate title so that it stylistically aligns with the **Top 10% style**.
- Keep the original meaning and tone natural.
- Add or remove emojis, special characters, or words if needed to fit the target pattern.
- Output only ONE final optimized title in JSON format:

{{
  "template": "{template}",
  "optimized_title": "..."
}}
"""
    return prompt

# %%
from openai import OpenAI
import json

MY_API_KEY=getpass.getpass("OpenAI API Key:")
client = OpenAI(api_key=MY_API_KEY)

def optimize_title_with_gpt(template, candidates, avg_features, top10_features):
    prompt = build_prompt(template, candidates, avg_features, top10_features)

    response = client.chat.completions.create(
        model="gpt-5",
        messages=[
            {"role": "system", "content": "You are a YouTube title optimization assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    try:
        return json.loads(response.choices[0].message.content)
    except:
        return {"template": template, "optimized_title": response.choices[0].message.content}
# Out:
# OpenAI API Key: ········

# %%
# cluster=2 데이터만
df_cluster2 = thumbnail_df[thumbnail_df['cluster'] == 2]

# 상위 10% 기준
threshold = df_cluster2['view_count'].quantile(0.9)
df_top10 = df_cluster2[df_cluster2['view_count'] >= threshold]

# 평균 피처 계산
title_features = [
    'title_length', 'word_count', 'emoji_count',
    'special_char_count', 'is_clickbait',
    'has_question_mark', 'has_exclamation'
]

avg_features = df_cluster2[title_features].mean().to_dict()
top10_features = df_top10[title_features].mean().to_dict()

# %%
from tqdm import tqdm

results = []

for template in tqdm(df_recommendations['template'].unique()):
    candidates = df_recommendations[df_recommendations['template'] == template]['title_candidate'].tolist()

    output = optimize_title_with_gpt(template, candidates, avg_features, top10_features)
    results.append(output)

df_final_titles = pd.DataFrame(results)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [12:08<00:00, 48.58s/it]

# %%
df_final_titles
# Out:
#                                     template                                        optimized_title
# 0                        {TOPIC} {SITUATION}           마인크래프트 탐험하기 | ⛏️ 신비한 바이옴·숨겨진 유적과 보물 던전 한 번에!
# 1                        {SITUATION} {TOPIC}              그냥 내비대로 가주세요: 기념일 드라이브, 예상 못한 코스로 가봅니다! 🎉
# 2                            {TOPIC} {EVENT}  퇴사자 당근마켓 레전드 | 실제 거래 모음 · 실화 썰 대방출! 노컷 하이라이트, 현웃 주의 🤯
# 3                     {SERIES} {TOPIC} {ENG}              [LG TWINS] 노래 모음 플리 | 응원감성 가득! Playlist 🎧
# 4                   {SERIES} {TOPIC} {EVENT}            [예고] 다크소울 플레이리스트 | 보스전·전투 몰입도 BGM 타격감 폭발! 🔥
# 5    {SERIES} {SITUATION} {TOPIC} {REACTION}            [웃소] 퇴사마려운 직장인 레전드 명장면 모음.zip 웃픈 회사생활 공감 😂!
# 6                  {TOPIC} {SITUATION} {LOC}         여행, 쓸쓸하지 않은 제주도｜혼자여도 따뜻한 감성 코스 추천!｜카페·해변·노을 🏝️
# 7        {ENG} {PERSON}의 {SITUATION} {TOPIC}             [ENG SUB] 아이유의 웃으면 안 되는 생일파티 🎂 레전드 모먼트 모음!
# 8   {SERIES} {TOPIC} {SITUATION} {NUM} {ENG}             [영업중] 돈가스 가게에서 생기는 일: 바삭 비밀 공개!🍽️ 노컷 00 EN
# 9                       {PERSON} {SITUATION}           감스트 인턴 첫 출근합니다! | 오늘 브이로그 비하인드 공개 👔 [현장 스케치]
# 10  {SERIES} {TOPIC} {SITUATION} {LOC} {NUM}             [sub] 베트남 먹방 부산 현지 맛 그대로! 로컬 추천 맛집 투어 🍜 00
# 11           {SERIES} {SITUATION} {REACTION}              [무공해] 해도 해도 너무한 순간들, 근데도 이상하게 진짜 공감합니다! 😂
# 12   {SERIES} {PERSON} {TOPIC} {EVENT} {NUM}              [사터뷰 시즌2] 사나 총결산 냉터뷰 00 | 레전드 모음·하이라이트! 🔥
# 13                 {TOPIC} {SITUATION} {ENG}          팝송 잘못된 플리 | 분위기 파괴 선곡 😅 [Wrong Pop Playlist]!
# 14               {TOPIC} {EVENT} {SITUATION}           [금지된 학교축제] 귀신의 집에서 완전 창자 빠지게 놀기 👻 공포주의/소름주의!

# %%
df_final_titles.to_csv('title_recommend_final.csv', index=0, encoding='utf-8')
